# %% [markdown]
# <a href="https://colab.research.google.com/github/nishta2005/cognicare/blob/main/mlmodelalzheimers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix, roc_auc_score)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('/content/train_preprocessed.csv')
test = pd.read_csv('test_preprocessed.csv')

X_train = train.drop(columns=['Diagnosis'])
y_train = train['Diagnosis']
X_test = test.drop(columns=['Diagnosis'])
y_test = test['Diagnosis']

print("Shape :", X_train.shape)
print("Test shape:", X_test.shape)

model = LogisticRegression(
    maxiter=1000,
    random_state=42,
    class_weight='balanced'
)
model.fit(X_train, y_train)
print("\n Model trained")

y_pred = model.predict(X_test)
y_pred_prob = model.predict_proba(X_test)[:,1]


print("ACCURACY")
print("Training Accuracy : {accuracy_score(y_train, model.predict(X_train)):.2%}")
print("Testing Accuracy : {accuracy_score(y_test, y_pred):.2%}")

print("CLASSIFICATION REPORT")
print(classification_report(y_test, y_pred, target_names=['No Alzheimers', 'Alzheimers']))

print("ROC AUC SCORE")
print(f"AUC :{roc_auc_score(y_test, y_pred_prob):. 4f}")

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels = ['No Alzheimers', 'Alzheimers'],
            ytickables = ['No Alzheimers', 'Alzheimers'])
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()


coefficients = pd.Series(
    np.abs(model.coef_[0]),
    index=X_train.columns
).sort_values(ascending=False)

plt.figure(figsize=(8,6))
coefficients.head(15).plot(kind='barh', color='steelblue')
plt.title('Top 15 Most Important Features')
plt.xlabel('coefficient magnitude')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

with open('alzheimers_model.pkl', 'wb') as f:
  pickle.dump(model,f)

print("model saved")

from google.colab import files
files.download('alzheimers_model.pkl')
print("model downloaded")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_403/739599262.py in <cell line: 0>()
#       1 train = pd.read_csv('/content/train_preprocessed.csv')
# ----> 2 test = pd.read_csv('test_preprocessed.csv')
#       3
#       4 X_train = train.drop(columns=['Diagnosis'])
#       5 y_train = train['Diagnosis']
#
# ...
